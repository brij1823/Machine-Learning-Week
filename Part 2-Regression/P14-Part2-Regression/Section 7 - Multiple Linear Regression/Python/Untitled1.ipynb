# %%
import scipy.io

# %%
mat = scipy.io.loadmat('S01.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'raw'])

# %%
mat['__header__']
# Out:
# b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Nov 19 12:02:43 2018'

# %%
mat['raw']
# Out:
# array([[(array([[(array([[500]], dtype=uint16), array([[62]], dtype=uint8), array([[array(['1'], dtype='<U1')],
#        [array(['2'], dtype='<U1')],
#        [array(['3'], dtype='<U1')],
#        [array(['4'], dtype='<U1')],
#        [array(['5'], dtype='<U1')],
#        [array(['6'], dtype='<U1')],
#        [array(['7'], dtype='<U1')],
#        [array(['8'], dtype='<U1')],
#        [array(['9'], dtype='<U1')],
#        [array(['10'], dtype='<U2')],
#        [array(['11'], dtype='<U2')],
#        [array(['12'], dtype='<U2')],
#        [array(['13'], dtype='<U2')],
#        [array(['14'], dtype='<U2')],
#        [array(['15'], dtype='<U2')],
#        [array(['16'], dtype='<U2')],
#        [array(['17'], dtype='<U2')],
#        [array(['18'], dtype='<U2')],
#        [array(['19'], dtype='<U2')],
#        [array(['20'], dtype='<U2')],
#        [array(['21'], dtype='<U2')],
#        [array(['22'], dtype='<U2')],
#        [array(['23'], dtype='<U2')],
# ...

# %%
mat['raw'][0][0][0][0][0]
# Out:
# (array([[500]], dtype=uint16), array([[62]], dtype=uint8), array([[array(['1'], dtype='<U1')],
#        [array(['2'], dtype='<U1')],
#        [array(['3'], dtype='<U1')],
#        [array(['4'], dtype='<U1')],
#        [array(['5'], dtype='<U1')],
#        [array(['6'], dtype='<U1')],
#        [array(['7'], dtype='<U1')],
#        [array(['8'], dtype='<U1')],
#        [array(['9'], dtype='<U1')],
#        [array(['10'], dtype='<U2')],
#        [array(['11'], dtype='<U2')],
#        [array(['12'], dtype='<U2')],
#        [array(['13'], dtype='<U2')],
#        [array(['14'], dtype='<U2')],
#        [array(['15'], dtype='<U2')],
#        [array(['16'], dtype='<U2')],
#        [array(['17'], dtype='<U2')],
#        [array(['18'], dtype='<U2')],
#        [array(['19'], dtype='<U2')],
#        [array(['20'], dtype='<U2')],
#        [array(['21'], dtype='<U2')],
#        [array(['22'], dtype='<U2')],
#        [array(['23'], dtype='<U2')],
#        [array(['24'], dtype='<U2')],
# ...
